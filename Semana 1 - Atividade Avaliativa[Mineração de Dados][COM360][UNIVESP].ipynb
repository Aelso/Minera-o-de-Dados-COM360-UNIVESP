# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Mineração de Dados** 🦘
# ###**Link**: https://ava.univesp.br/ultra/courses/_5991_1/cl/outline 🛸
# ##**Prof.**Dr. Higor Amario de Souza 🐅
# ##**Aluno: Aelso Rocha Brito** 🐸
# ##**notebook**ComAnotaçõesDasVideoaulas 🧧
# ## **Semestre:** 01.2022 ⚾
# ---

# %% [markdown]
# ## **Semana 1 - Atividade Avaliativa[Mineração de Dados][COM360][UNIVESP]** 💾

# %% [markdown]
# **PERGUNTA 1** 🧸
#
# O crescimento exponencial na quantidade de dados coletados e armazenados na Internet ou em empresas trouxe várias oportunidades de uso desses dados para gerar informações relevantes, mas trouxe também alguns problemas para lidar com essas bases de dados. Indique qual das alternativas abaixo é correta sobre um problema existente ao lidar com essas bases de dados.

# %% [markdown]
# O crescimento dos dados gerados torna difícil manter os modelos dos bancos de dados relacionais.

# %% [markdown]
# Não existem técnicas automatizadas para realizar a análise desses dados.

# %% [markdown]
# Não há espaço disponível nos centros de dados de provedores de nuvem para armazenar o crescente número de dados que são gerados.

# %% [markdown]
# Não há demanda por informações vindas desses dados.

# %% [markdown]
# 🔘 **Algumas bases crescem tanto que não é possível realizar a análise dos dados manualmente.** 🧝

# %% [markdown]
# **Comentário da resposta:**
#
# As bases de dados são cada vez maiores, o que dificulta a análise manual, já que a capacidade humana de lidar com grandes quantidades de informações é limitada. Felizmente, existem técnicas automatizadas para auxiliar a análise de dados, possibilitando atender à demanda crescente por informação baseada em dados.

# %% [markdown]
# **PERGUNTA 2** 🦉
#
# ____________ de dados é o processo que explora _________ de dados usando algoritmos adequados para obter _____________.
#
# Sobre o significado do termo mineração de dados, qual das alternativas abaixo completa corretamente as lacunas da frase acima?

# %% [markdown]
# 🅾 **Mineração; bases; conhecimento.** 🎃

# %% [markdown]
# Produção; mineração; análises.

# %% [markdown]
# Mineração; sequências; conhecimento.

# %% [markdown]
# Geração; bases; dados.

# %% [markdown]
# Redução; mineração; dados.

# %% [markdown]
# **Comentário da resposta:**
#
# Mineração de dados é o processo que explora bases de dados usando algoritmos adequados para obter conhecimento.

# %% [markdown]
# **PERGUNTA 3** 🦖
#
# Sobre o processo de descoberta de conhecimento em bases de dados (KDD), qual das alternativas abaixo apresenta a sequência correta na qual ocorrem as etapas de KDD?

# %% [markdown]
# Pré-processamento, mineração de dados, seleção, definição dos objetivos, transformação e interpretação/avaliação.

# %% [markdown]
# ⏹ **Definição dos objetivos, seleção, pré-processamento, transformação, mineração de dados e interpretação/avaliação.** 🍉

# %% [markdown]
# Definição dos objetivos, pré-processamento, seleção, transformação, interpretação/avaliação e mineração de dados.

# %% [markdown]
# Mineração de dados, seleção, definição dos objetivos, transformação, pré-processamento e interpretação/avaliação.

# %% [markdown]
# Interpretação/avaliação, seleção, transformação, pré-processamento, mineração de dados e definição dos objetivos.

# %% [markdown]
# **Comentário da resposta:**
#
# A sequência de etapas do processo de KDD é a seguinte: definição dos objetivos, seleção, pré-processamento, transformação, mineração de dados e interpretação/avaliação.

# %% [markdown]
# **PERGUNTA 4** 📡
#
# Considerando as características do processo de conhecimento em bases de dados (KDD), indique a alternativa que contém somente afirmações corretas:
#
# I. O processo de KDD deve partir de hipóteses preestabelecidas, que podem ser confirmadas ou negadas.
#
# II. O KDD é uma atividade multidisciplinar.
#
# III. O KDD tem o objetivo de transformar grandes volumes de dados em conhecimento.
#
# IV. O KDD é uma das etapas da mineração de dados.

# %% [markdown]
# III e IV, apenas.

# %% [markdown]
# I, II, III e IV.

# %% [markdown]
# I, II e III, apenas.

# %% [markdown]
# ⚾**II e III, apenas.** 🐇

# %% [markdown]
# I e III, apenas.

# %% [markdown]
# **Comentário da resposta:**
#
# O processo de KDD é uma atividade multidisciplinar, envolvendo as áreas de computação e matemática, assim como a área do domínio do problema abordado. A ideia central é transformar grandes volumes de dados em conhecimento útil para a tomada de decisão. Ao iniciar o KDD, não se deve assumir nenhuma hipótese prévia. Já a mineração de dados é uma das etapas de KDD, e não o contrário.
