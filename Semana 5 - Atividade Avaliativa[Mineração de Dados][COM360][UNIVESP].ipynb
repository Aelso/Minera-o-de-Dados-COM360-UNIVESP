# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Mineração de Dados** 🦘
# ###**Link**: https://ava.univesp.br/ultra/courses/_5991_1/cl/outline 🛸
# ##**Prof.**Dr. Higor Amario de Souza 🐅
# ##**Aluno: Aelso Rocha Brito** 🐸
# ##**notebook**ComAnotaçõesDasVideoaulas 🧧
# ## **Semestre:** 01.2022 ⚾
# ---

# %% [markdown]
# ## **Semana 5 - Atividade Avaliativa[Mineração de Dados][COM360][UNIVESP]** ⚾

# %% [markdown]
# **PERGUNTA 1** 🗽
#
# A partir da matriz de distância abaixo, escolha a alternativa que contém o dendograma resultante do algoritmo single-linkage. Na matriz, as linhas e colunas de A e E representam objetos a serem agrupados:

# %% [markdown]
# |  |A|B|C|D|E|
# |--|-|-|-|-|-|
# |A |0|3|6|7|5|
# |B |3|0|4|2|9|
# |C |6|4|0|8|1|
# |D |7|2|8|0|3|
# |E |5|9|1|3|0|

# %% [markdown]
# <INPUT TYPE="RADIO" NAME="OPCAO1" VALUE="op1">

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <INPUT TYPE="RADIO" NAME="OPCAO2" VALUE="op2">

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <INPUT TYPE="RADIO" NAME="OPCAO3" VALUE="op3">

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <INPUT TYPE="RADIO" NAME="OPCAO4" VALUE="op4">

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <INPUT TYPE="RADIO" NAME="OPCAO5" VALUE="op5">

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Comentário da resposta:**
#
# O algoritmo single-linkage compara as distâncias entre os objetos a serem agrupados, escolhendo primeiro os objetos com a menor distância, que vão formar um novo grupo. O processo se repete até que haja um único grupo contendo todos os objetos. A sequência de agrupamentos é: C e E; B e D; A, B e D; e A, B, C, D e E, que ocorrem, respectivamente, nas distâncias 1, 2, 3 e 4.

# %% [markdown]
# **PERGUNTA 2** ☕
#
# Sobre as características da análise de grupos, considere as afirmações abaixo:
#
# I. A análise de grupos considera cada atributo (característica) de um conjunto de dados separadamente para dividi-los em subconjuntos.
#
# II. Objetos de um grupo possuem características similares.
#
# III. A análise de grupos é usada em áreas como mineração de dados, aprendizado de máquina e análise de imagens.
#
# IV. A análise de grupos só pode ser usada em dados categóricos.
# Agora escolha a alternativa que contém somente afirmações corretas:

# %% [markdown]
# **II e III, apenas.** 🟡

# %% [markdown]
# I, II e III, apenas.

# %% [markdown]
# I e III, apenas.

# %% [markdown]
# II e IV, apenas.

# %% [markdown]
# III e IV, apenas.

# %% [markdown]
# **Comentário da resposta:**
#
# A análise de grupos usa as diversas características de um conjunto de dados simultaneamente para agrupá-los com base na similaridade dessas características. Esse tipo de análise é usado em várias áreas, incluindo mineração de dados, aprendizagem de máquina e análise de imagens. É possível usar dados numéricos na análise de grupos.

# %% [markdown]
# **PERGUNTA 3** 🤟
#
# Sobre as etapas do processo de agrupamento, observe a imagem a seguir. Indique a alternativa que apresenta corretamente quais são as etapas no diagrama mostrado na figura:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I. Representação dos grupos.
#
# II. Pré-processamento dos dados.
#
# III. Definição da medida de similaridade.
#
# IV. Avaliação do agrupamento.
#
# V. Execução do método de agrupamento.

# %% [markdown]
# 1 – I; 2 - II; 3 - V; 4 - IV; 5 - III

# %% [markdown]
# **1 – II; 2 - III; 3 - V; 4 - I; 5 - IV** 🦥

# %% [markdown]
# 1 – I; 2 - III; 3 - II; 4 - V; 5 - IV

# %% [markdown]
# 1 – III; 2 - I; 3 - IV; 4 - II; 5 - V

# %% [markdown]
# 1 – II; 2 - I; 3 - V; 4 - III; 5 - IV

# %% [markdown]
# **Comentário da resposta:**
#
# A ordem das etapas, de 1 a 5, é, respectivamente: pré-processamento dos dados, definição da medida de similaridade, execução do método de agrupamento, representação dos grupos e avaliação do agrupamento.

# %% [markdown]
# **PERGUNTA 4** ⭕
#
# A análise de grupos é o processo de _____________ um conjunto de dados em _____________ de forma que os objetos em cada grupo compartilhem características ___________ com relação a alguma medida de _____________ ou distância.
#
# Escolha a alternativa que completa as lacunas da frase acima de forma correta:

# %% [markdown]
# **particionar; subconjuntos; comuns; similaridade** 🚂

# %% [markdown]
# particionar; ordem; distintas; particularidade

# %% [markdown]
# organizar; bloco; distintas; particularidade

# %% [markdown]
# unir; paralelo; distintas; particularidade

# %% [markdown]
# unir; ordem; comuns; similaridade

# %% [markdown]
# **Comentário da resposta:**
#
# A análise de grupos é o processo de particionar um conjunto de dados em subconjuntos de forma que os objetos em cada grupo compartilhem características comuns com relação a alguma medida de similaridade ou distância.

# %% [markdown]
# **PERGUNTA 5** 🐙
#
# Escolha a alternativa que contém o algoritmo de agrupamento correto de acordo com as características descritas abaixo.
#
# I. Usa um raio de vizinhança para determinar os objetos que pertencem a um mesmo grupo.
#
# II. Objetos que não forem adicionados a um grupo são considerados como ruídos.
#
# III. Os agrupamentos são feitos com base na densidade dos objetos no espaço.

# %% [markdown]
# single-linkage.

# %% [markdown]
# fuzzy k-médias.

# %% [markdown]
# **DBSCAN.**  📻

# %% [markdown]
# árvore geradora mínima.

# %% [markdown]
# k-medoides.

# %% [markdown]
# **Comentário da resposta:**
#
# O algoritmo DBSCAN faz agrupamentos com base na densidade dos objetos no espaço. Para isso, usa um raio de vizinhança para determinar os objetos que pertencem a um mesmo grupo. Objetos que não forem adicionados a um grupo são considerados como ruídos.

# %% [markdown]
# **PERGUNTA 6** 🐆
#
# Sobre as medidas de similaridade para dados nominais, use a amostra de uma base de dados de veículos abaixo para calcular a dissimilaridade entre os dois objetos através da comparação simples entre os seus atributos. Escolha a alternativa que contém o valor correto de dissimilaridade entre os objetos:

# %% [markdown]
# |Tipo     |Cor   |Ano |País  |Câmbio    |Motor   |Volante      |
# |---------|------|----|------|----------|--------|-------------|
# |Sedan    |Branco|2022|Brasil|Automático|Elétrico|Lado esquerdo|
# |Esportivo|Branco|2022| Brasil|Manual   |Elétrico|Lado esquerdo|

# %% [markdown]
# 1,4

# %% [markdown]
# ~0,5833

# %% [markdown]
# 0,75

# %% [markdown]
# ~ 0,7143

# %% [markdown]
# **~ 0,2857** 🎃

# %% [markdown]
# **Comentário da resposta:**
#
# A dissimilaridade entre os objetos é aproximadamente 0,2857.
#
# $d_{ij}=\frac{m-M}{m}$
#
# i e j :objetos
#
# M :atributos iguais
#
# m :total de atributos
#
# $d_{ij}=\frac{7 -5}{7}$
#
# $d_{ij}=0,2857...$

# %% [markdown]
# **PERGUNTA 7** 🏂
#
# Calcule o número de possibilidades de agrupamento para um conjunto contendo 30 objetos e 2 grupos. Escolha a alternativa com a resposta correta.

# %% [markdown]
# 1.073.741.822

# %% [markdown]
# 524.287.015

# %% [markdown]
# 386.524.312

# %% [markdown]
# 1.276.945.540

# %% [markdown]
# **536.870.911** 🦉

# %% [markdown]
# **Comentário da resposta:**
#
# De acordo com a fórmula que calcula a complexidade de agrupamento, dado um número de objetos e um número de grupos, são 536.870.911 possibilidades de agrupamento.
#
# $N_{(n,k)}=\frac{1}{k!} \cdot Σ_{i =1}^k (-1)^{k-1}\cdot (\frac{k}{i})\cdot i^{n}$
#
# $N_{(30,2)}=\frac{1}{2!} \cdot Σ_{1=i}^2(-1)^{2-i}\cdot(\frac{2}{i })\cdot i^{30}$
#
# $N_{(30,2)}=0,5 \cdot ((-1^1 \cdot 2 \cdot 1^{30}))+(-1^0 \cdot 1 \cdot 2^{30}))$
#
# $N_{(30,2)}=0,5\cdot((2))+(1.073.741.824))$
#
# $N_{(30,2)}=0,5\cdot(1.073.741.822)$
#
# $N_{(30,2)}=536.870.911$

# %% [markdown]
# **PERGUNTA 8** 🥚
#
# Escolha a alternativa que contém o algoritmo de agrupamento correto de acordo com as características descritas abaixo:
#
# I. Algoritmo de agrupamento particional.
#
# II. O centro do grupo é o valor de um dos objetos existentes no grupo que possui a menor dissimilaridade em relação aos demais objetos.
#
# III. Sua função de custo é usada como critério de parada do algoritmo.

# %% [markdown]
# DBSCAN

# %% [markdown]
# complete-linkage

# %% [markdown]
# k-médias

# %% [markdown]
# árvore geradora mínima

# %% [markdown]
# **k-medoides** 🤡

# %% [markdown]
# **Comentário da resposta:**
#
# O k-medoides é um algoritmo de agrupamento particional. O centro do grupo, chamado medoide, é o valor de um dos objetos existentes no grupo. A função de custo do k-medoides é usada como critério de parada do algoritmo.
