# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Mineração de Dados** 🦘
# ###**Link**: https://ava.univesp.br/ultra/courses/_5991_1/cl/outline 🛸
# ##**Prof.**Dr. Higor Amario de Souza 🐅
# ##**Aluno: Aelso Rocha Brito** 🐸
# ##**notebook**ComAnotaçõesDasVideoaulas 🧧
# ## **Semestre:** 01.2022 ⚾
# ---

# %% [markdown]
# ## **Semana 4 - Atividade Avaliativa[Mineração de Dados][COM360][UNIVESP]** 👽

# %% [markdown]
# **PERGUNTA 1** 🌐
#
# Observe a árvore de decisão apresentada abaixo. Escolha a alternativa que contém afirmações corretas sobre o modelo de árvore construído:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# I. As classes da árvore são “a pé”, “ônibus” e “táxi”.
#
# II. Os atributos do conjunto de dados usados para tomada de decisão na árvore são “tempo", “dinheiro” e “modo de transporte”.
#
# III. Se o tempo for maior que uma hora, a classificação poderá ser feita como “a pé” ou “táxi”.
#
# IV. Os nós “tempo” e “dinheiro” são chamados, respectivamente, de nó raiz e nó interno.
#
# V. Um objeto só será classificado como “táxi” se o tempo for menor ou igual a uma hora e se o dinheiro for maior que R$10.

# %% [markdown]
# **I, IV e V, apenas.** 🍪

# %% [markdown]
# II e III, apenas.

# %% [markdown]
# III, IV e V, apenas.

# %% [markdown]
# I, II, IV e V, apenas.

# %% [markdown]
# I, III e IV, apenas

# %% [markdown]
# **Comentário da resposta:**
#
# Quanto à estrutura da árvore, as classes são “a pé”, “ônibus” e “táxi”, e os nós “tempo” e “dinheiro” são respectivamente o nó raiz e nó interno. Um objeto só será classificado como “táxi” se o tempo for menor ou igual a uma hora e se o dinheiro for maior que R$10. Já a afirmação sobre os atributos usados para tomada de decisão está errada, pois apenas “tempo" e “dinheiro” são usados para a decisão. Também é errada a afirmação sobre a classificação quando o tempo é maior que uma hora. Nesse caso, a classe será somente “a pé”.

# %% [markdown]
# **PERGUNTA 2** 🎈
#
# Sobre as etapas de classificação supervisionada, escolha a alternativa que associa corretamente as tarefas abaixo com as etapas de treinamento e teste:
#
# 1. Treinamento.
#
# 2. Teste.
#
# I. Os dados rotulados são usados para preparar a técnica de classificação.
#
# II. O desempenho da técnica de classificação é avaliado.
#
# III. Os dados não rotulados são classificados.
#
# IV. Etapa inicial da classificação supervisionada.

# %% [markdown]
# 1 – I e II; 2 – III e IV.

# %% [markdown]
# **1 – I e IV; 2 – II e III.** 👌

# %% [markdown]
# 1 – II e IIII; 2 – I e IV.

# %% [markdown]
# 1 – III e IV; 2 – I e II.

# %% [markdown]
# 1 – II e IV; 2 – I e III.

# %% [markdown]
# **Comentário da resposta:**
#
# Durante o treinamento, que é a etapa inicial da classificação, os dados rotulados são usados para preparar a técnica de classificação. Na etapa seguinte, de teste, os dados rotulados são classificados e o desempenho da técnica de classificação é avaliado.

# %% [markdown]
# **PERGUNTA 3** 🔥
#
# Escolha a alternativa que contém somente características que fazem parte da classificação supervisionada:
#
# **I - Predizer a classe de novos registros a partir de registros conhecidos.**
#
# II - Ausência de conhecimento das possíveis classes às quais os registros podem pertencer.
#
# **III - Separação dos dados em etapas de treinamento e teste.**
#
# IV - Análise de correlação entre os atributos do conjunto de dados.

# %% [markdown]
# II e III, apenas.

# %% [markdown]
# **I e III, apenas.** 🔴

# %% [markdown]
# I, II e III, apenas.

# %% [markdown]
# II, III e IV, apenas.

# %% [markdown]
# I, II e IV, apenas.

# %% [markdown]
# **Comentário da resposta:**
#
# A classificação supervisionada serve para fazer predição de novos registros com base em registros já conhecidos. É o conhecimento das possíveis classes existentes que permite “supervisionar” o processo de análise. Para construir o modelo de predição, os dados são separados em etapas de treinamento e teste. Já a correlação é realizada durante a análise descritiva de dados.

# %% [markdown]
# **PERGUNTA 4** ☕
#
# Relacione os tipos de estruturas nos quais os algoritmos de classificação podem ser separados com as afirmações que caracterizam tais tipos de estruturas. Escolha a alternativa que contém as relações corretas.
#
# 1. Probabilísticos.
#
# 2. Baseados em conhecimento.
#
# 3. Conexionistas.
#
# 4. Baseados em distância.
#
# I. Calculam a diferença entre o objeto a ser classificado e os demais objetos rotulados.
#
# II. Possuem um conjunto de regras que determinam a classe de um objeto.
#
# III. Permitem atribuir uma chance de um objeto pertencer a uma ou mais classes.
#
# IV. São formados por redes (nós) interconectadas.

# %% [markdown]
# 1 – II; 2 – III; 3 – I; 4 – IV.

# %% [markdown]
# 1 – III; 2 – IV; 3 – I; 4 – II.

# %% [markdown]
# 1 – I; 2 – II; 3 – IV; 4 – III.

# %% [markdown]
# **1 – III; 2 – II; 3 – IV; 4 – I.** ✊

# %% [markdown]
# 1 – I; 2 – IV; 3 – III; 4 – II.

# %% [markdown]
# **Comentário da resposta:**
#
# Entre os tipos de estruturas dos diferentes algoritmos de classificação temos os probabilísticos, que permitem atribuir uma chance de um objeto pertencer a uma ou mais classes. Os baseados em conhecimento possuem um conjunto de regras que determinam a classe de um objeto. Os conexionistas são formados por redes (nós) interconectadas. Já os baseados em distância calculam a diferença entre o objeto a ser classificado e os demais objetos rotulados.

# %% [markdown]
# **PERGUNTA 5** 🦌
#
# Um conjunto de dados de clientes que solicitaram empréstimo bancário, contendo 900 registros, foi classificado por um algoritmo de classificação supervisionada. As classes binárias são “conceder” (classe alvo) e “negar”.
#
# A partir da matriz de confusão abaixo, calcule e indique a alternativa que contém os valores corretos de acurácia, erro, precisão e revogação obtidos, respectivamente. Os valores estão arredondados para duas casas decimais:

# %% [markdown]
# ||||||
# |-------------------|-|--------------|--|-|
# |Matriz de confusão ||Classe predita ||
# |                   ||Conceder|Negar|
# |Classe original    |Conceder|500 |60|
# |                   |Negar |40|300|

# %% [markdown]
# 0,89; 0,11; 0,92; 0,89

# %% [markdown]
# 0,62; 0,38; 0,93; 0,89

# %% [markdown]
# 0,89; 0,11; 0,89; 0,93

# %% [markdown]
# 0,62; 0,38; 0,17; 0,12

# %% [markdown]
# **0,89; 0,11; 0,93; 0,89** 🦅

# %% [markdown]
# **Comentário da resposta:**
#
# Os valores corretos para acurácia, erro, precisão e revogação são, respectivamente: 0,89; 0,11; 0,93; 0,89.
#
# Acurácia = (500 + 300) / (500 + 40 + 300+ 60) = 800 / 900 = 0,89
#
# Erro = 1 - acurácia = 1 – 0.89 = 0,11
#
# Precisão = 500 / 40 + 500 = 500 / 540 = 0,93
#
# Revogação = 500 / 60 + 500 = 500 / 560 = 0,89

# %% [markdown]
# **PERGUNTA 6** 👽
#
# Leia os exemplos de análise de dados abaixo e escolha a alternativa que contém somente exemplos em que se pode usar classificação supervisionada.
#
# I – Um banco possui uma carteira de clientes e deseja usá-la para analisar solicitações de empréstimo de clientes que podem se tornar inadimplentes.
#
# II – Uma loja possui dados dos seus clientes, como seus perfis e histórico de compras, e pretende usá-los para oferecer produtos específicos de acordo com determinadas categorias às quais esses clientes pertencem.
#
# III – Um supermercado possui dados sobre os produtos que vende e compra, e pretende identificar quais produtos estão mais relacionados para fazer ofertas conjuntas.

# %% [markdown]
# II, apenas.

# %% [markdown]
# III, apenas.

# %% [markdown]
# **I e II, apenas.** 🦖

# %% [markdown]
# I, II e III.

# %% [markdown]
# I, apenas.

# %% [markdown]
# **Comentário da resposta:**
#
# Classificação supervisionada pode ser usada quando temos tarefas nas quais se pretende predizer um conjunto de dados com base em características e grupos previamente conhecidos, o que acontece no caso dos exemplos de empréstimo bancário e de ofertas de produtos específicos para categorias de clientes distintas. Já a identificação de relações entre produtos não é uma tarefa que possa ser feita por classificação supervisionada, pois trata-se da descoberta de relações sobre as quais não se têm conhecimento prévio.

# %% [markdown]
# **PERGUNTA 7** ⏹
#
# Sobre validação cruzada, escolha a alternativa que contém somente afirmações verdadeiras.
#
# I. A validação cruzada pode ser usada para identificar o ponto de parada do treinamento dos algoritmos de classificação supervisionada.
#
# II. A validação cruzada é usada durante a etapa de pré-processamento dos dados, antes da separação dos dados em treinamento e teste.
#
# III. A validação cruzada pode ser usada para validar o desempenho dos algoritmos de classificação supervisionada.
#
# IV. A validação cruzada serve para rotular os dados de um conjunto para uso em classificação supervisionada.

# %% [markdown]
# I, II e IV, apenas.

# %% [markdown]
# I, III e IV, apenas.

# %% [markdown]
# **I e III, apenas.** 🧯

# %% [markdown]
# II e III, apenas.

# %% [markdown]
# II e IV, apenas.

# %% [markdown]
# **Comentário da resposta:**
#
# A validação cruzada pode ser usada tanto para identificar o ponto de parada do treinamento quanto para validar o desempenho dos algoritmos de classificação supervisionada. A validação cruzada não é usada durante a etapa de pré-processamento e não serve para rotular dados.

# %% [markdown]
# **PERGUNTA 8** 🥚
#
# Sobre o algoritmo k-vizinhos mais próximos (k-NN), escolha a alternativa que contém somente afirmações corretas:
#
# I. Para objetos representados numericamente, usa-se a distância Euclidiana para classificá-los.
#
# II. O valor de k é determinado de acordo com o número de objetos do conjunto de dados.
#
# III. O k-NN é um algoritmo classificador baseado em distância.
#
# IV. Também é conhecido como algoritmo preguiçoso, pois só é executado quando é necessário classificar um novo objeto.

# %% [markdown]
# **I, III e IV, apenas.** 😂

# %% [markdown]
# I, II, III e IV.

# %% [markdown]
# I e IV, apenas.

# %% [markdown]
# II e III, apenas.

# %% [markdown]
# II, III e IV, apenas.

# %% [markdown]
# **Comentário da resposta:**
#
# No k-NN, a distância Euclidiana é usada quando os objetos são representados numericamente. O valor de k é determinado por tentativa e erro, e não tem relação com o número de objetos do conjunto de dados. O k-NN é um algoritmo classificador baseado em distância e também é conhecido como algoritmo preguiçoso.
