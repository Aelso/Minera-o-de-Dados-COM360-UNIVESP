# %% [markdown]
# ##**Bacharelado em Ciência de Dados - Univesp** 🏆
# ---
# ###**Disciplina - Mineração de Dados** 🦘
# ###**Link**: https://ava.univesp.br/ultra/courses/_5991_1/cl/outline 🛸
# ##**Prof.**Dr. Higor Amario de Souza 🐅
# ##**Aluno: Aelso Rocha Brito** 🐸
# ##**notebook**ComAnotaçõesDasVideoaulas 🧧
# ## **Semestre:** 01.2022 ⚾
# ---

# %% [markdown]
# ## **Semana 2 - Atividade Avaliativa[Mineração de Dados][COM360][UNIVESP]** 🔥

# %% [markdown]
# **PERGUNTA 1** 🎨
#
# Sobre pré-processamento de dados, indique a alternativa que contém os três tipos de problemas que dados podem apresentar.

# %% [markdown]
# Inconsistência, redundância e ausência.

# %% [markdown]
# Inconsistência, ruído e inexistência.

# %% [markdown]
# **Incompletude, inconsistência e ruído.** 🍓

# %% [markdown]
# Redundância, ruído e inexistência.

# %% [markdown]
# Incompletude, ausência e redundância.

# %% [markdown]
# **Comentário da resposta:**
#
# Os três tipos de problema em dados são incompletude, inconsistência e ruído. A incompletude refere-se a valores, atributos ou objetos ausentes. A inconsistência tem a ver com valores fora do domínio ou discrepantes. Já ruído refere-se a valores que podem resultar em inconsistências durante a extração dos resultados.

# %% [markdown]
# **PERGUNTA 2** 🔴
#
# Quanto às categorias de estrutura de dados, escolha a alternativa que contém a sequência correta de formatos de arquivos estruturados, semiestruturados e não estruturados.

# %% [markdown]
# Planilha (CSV), arquivo de áudio (MP3) e arquivo de imagem (JPG).

# %% [markdown]
# Arquivo de texto (TXT), arquivo de dados (XML) e tabela de banco de dados (DBF).

# %% [markdown]
# E-mail (EML), arquivo de texto (TXT) e arquivo de texto (PDF).

# %% [markdown]
# Tabela de banco de dados (DBF), arquivo de texto (PDF) e planilha (CSV).

# %% [markdown]
# **Tabela de banco de dados (DBF), e-mail (EML) e arquivo de texto (TXT).** 👊

# %% [markdown]
# **Comentário da resposta:**
#
# A resposta correta é a sequência: tabela de banco de dados (DBF), e-mail (EML) e arquivo de texto (TXT).
#
# Arquivos estruturados como a extensão DBF possuem campos com dados rigidamente definidos. Já arquivos de e-mail, como EML, são semiestruturados, pois possuem uma estrutura parcial, com alguns campos definidos. Arquivos de texto, áudio ou imagem (por exemplo, TXT, MP3 e JPG) são não estruturados, sendo mais difíceis de analisar.

# %% [markdown]
# **PERGUNTA 3** 🥏
#
# Sobre redução do número de dados, escolha a alternativa que contém o nome do método de amostragem correto de acordo com o processo descrito a seguir:
#
# Os objetos (registros) do conjunto de dados pertencem a um de cinco grupos distintos. A amostra foi obtida escolhendo 10% dos objetos de cada grupo.

# %% [markdown]
# **Amostragem estratificada**. 🧳

# %% [markdown]
# Amostragem aleatória com substituição.

# %% [markdown]
# Amostragem aleatória sem substituição.

# %% [markdown]
# Amostragem por grupo.

# %% [markdown]
# Amostragem sistemática.Amostragem sistemática.

# %% [markdown]
# **Comentário da resposta:**
#
# A amostragem citada no processo acima é a estratificada, na qual a proporção de objetos de cada grupo é mantida. É importante observar que, embora a amostragem por grupo leve em consideração a quantidade de grupos existentes ao selecionar os objetos, não há garantia de manter a proporcionalidade na amostra resultante.

# %% [markdown]
# **PERGUNTA 4** 🐸
#
# Sobre os métodos de imputação de valores, indique a alternativa que contém somente afirmações corretas.
#
# I. Pode-se remover objetos que possuam valores ausentes.
#
# II. Pode-se imputar manualmente os valores ausentes.
#
# III. Não é possível usar um valor único para imputar valores ausentes de todos os objetos.
#
# IV. Pode-se usar a média de um atributo para imputar valores ausentes.

# %% [markdown]
# II e IV, apenas.

# %% [markdown]
# **I, II e IV, apenas.** 🦥

# %% [markdown]
# I e II, apenas.

# %% [markdown]
# III e IV, apenas.

# %% [markdown]
# I, II, III e IV.

# %% [markdown]
# **Comentário da resposta:**
#
# Ao lidar com valores ausentes, uma estratégia possível é remover os objetos que possuem esses valores. Além disso, é possível imputar valores manualmente ou usar a média dos valores de um atributo para imputar automaticamente os valores ausentes. Também é possível atribuir um valor único (global) para imputar valores ausentes.

# %% [markdown]
# **PERGUNTA 5** 🦈
#
# Considerando a existência de valores ausentes em uma base de dados, indique a alternativa que contém somente afirmações corretas.
#
# I. Um valor ausente pode ser representado por um valor específico, um espaço em branco ou um símbolo.
#
# II. A imputação tem o objetivo de estimar os valores ausentes com base nas informações presentes no conjunto de dados.
#
# III. É sempre necessário remover todos os registros que possuam valores ausentes para fazer a limpeza da base de dados.
#
# IV. Valores discrepantes (outliers) também podem ser modificados durante a limpeza dos dados.

# %% [markdown]
# a. I, III e IV, apenas.

# %% [markdown]
# b. III, apenas.

# %% [markdown]
# c. **I, II e IV, apenas**. 🐝

# %% [markdown]
# d. I e II, apenas.

# %% [markdown]
# e. I e IV, apenas.

# %% [markdown]
# **Comentário da resposta:**
#
# Um valor ausente pode ser representado por um valor específico, um espaço em branco ou símbolo. Podemos usar imputação para preencher valores presentes no conjunto de dados tanto para valores ausentes quanto para valores discrepantes.

# %% [markdown]
# **PERGUNTA 6** 🗽
#
# Sobre integração de dados, escolha a alternativa que faz a associação correta entre os nomes e as definições dos três aspectos a serem observados durante a fase de integração.
#
# 1. Redundância
# 2. Duplicidade
# 3. Conflitos
#
# I. Tipo de redundância em que objetos ou atributos aparecem repetidamente nas bases de dados.
#
# II. Ocorre quando um mesmo objeto possui diferentes valores nas bases de dados.
#
# III. Ocorre quando um mesmo objeto ou atributo pode ser obtido a partir de mais de um objeto ou atributo das bases de dados.

# %% [markdown]
# a. 1 - I; 2 - III; 3 - II

# %% [markdown]
# b. 1 - III; 2 - II; 3 - I

# %% [markdown]
# c. **1 - III; 2 - I; 3 - II**	 🦄

# %% [markdown]
# d. 1 - II; 2 - III; 3 - I

# %% [markdown]
# e. 1 - I; 2 - II; 3 - III

# %% [markdown]
# **Comentário da resposta:**
#
# Redundância é o aspecto mais geral que ocorre quando um mesmo objeto ou atributo pode ser obtido a partir de mais de um objeto ou atributo das bases de dados. A duplicidade é um tipo de redundância em que objetos ou atributos aparecem repetidamente nas bases de dados. Já o conflito ocorre quando um mesmo objeto possui diferentes valores nas bases de dados.
